# %% [markdown]
# <a href="https://colab.research.google.com/github/QiyuLiu21/L04/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/content/drive/MyDrive/Unemployment_Insurance_Initial_Claims_By_Region_By_Month__Beginning_2003.csv',
               index_col='Period Ending' #set panda index 'period ending'
               , parse_dates = True
               )

# %%
df
# Out:
#                          Region  Initial Claims
# Period Ending
# 2003-07-31              Capital            4326
# 2003-07-31     Central New York            4366
# 2003-07-31         Finger Lakes            7095
# 2003-07-31        Hudson Valley            8454
# 2003-07-31          Long Island           13575
# ...                         ...             ...
# 2020-12-31        Mohawk Valley            5489
# 2020-12-31        New York City           84695
# 2020-12-31        North Country            4286
# 2020-12-31        Southern Tier            5956
# 2020-12-31     Western New York           17039
#
# [2100 rows x 2 columns]

# %%
sns.lineplot(x = df.index,
             y = df['Initial Claims'],
             hue = df['Region'],
             err_style = None
            )
sns.set(rc = {'figure.figsize': (18, 15)})
plt.xticks(rotation = 45);

# %%
df.groupby(by=df['Region'],axis=0,).sum(numeric_only = True)
# Out:
#                   Initial Claims
# Region
# Capital                  1125444
# Central New York          974337
# Finger Lakes             1503748
# Hudson Valley            2114819
# Long Island              2983939
# Mohawk Valley             660976
# New York City            9006397
# North Country             579647
# Southern Tier             746375
# Western New York         2110859

# %%
region = str(input('Enter Region : '))
claims = df[df['Region']==region]['Initial Claims']
print(claims)

# %%
var = 'TotalBsmtSF'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
# Concatenate  df_train['SalePrice'] and df_train[var] along the particular axis with optional set logic along the other axes.

data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
